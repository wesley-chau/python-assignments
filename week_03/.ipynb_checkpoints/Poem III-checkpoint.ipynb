# %%
#POEM III: a poetic letter to my childhood home 
#06/28/2021

# %%
#splitting body of text into a list

text = "a special place conjoined childhood bedrooms bike rides family dinner family movie nights sleepovers sleepless nights dreaming daytime runs swims christmas girlfriend boyfriend best friends pasta nights piano playing piano lessons brunch baking with cae learning recipes from mom learning how to drive learning how to operate a bbq fireplace bathtub sleeping in the hawk that lived above us takeout home cooked meals a special place i call home"
split_text = text.split(' ')
print(split_text)
# Out:
# ['a', 'special', 'place', 'conjoined', 'childhood', 'bedrooms', 'bike', 'rides', 'family', 'dinner', 'family', 'movie', 'nights', 'sleepovers', 'sleepless', 'nights', 'dreaming', 'daytime', 'runs', 'swims', 'christmas', 'girlfriend', 'boyfriend', 'best', 'friends', 'pasta', 'nights', 'piano', 'playing', 'piano', 'lessons', 'brunch', 'baking', 'with', 'cae', 'learning', 'recipes', 'from', 'mom', 'learning', 'how', 'to', 'drive', 'learning', 'how', 'to', 'operate', 'a', 'bbq', 'fireplace', 'bathtub', 'sleeping', 'in', 'the', 'hawk', 'that', 'lived', 'above', 'us', 'takeout', 'home', 'cooked', 'meals', 'a', 'special', 'place', 'i', 'call', 'home']

# %%
for t in split_text:
    print(t)
# Out:
# place
# to
# us
# christmas
# home
# boyfriend
# childhood
# baking
# in
# operate
# sleepless
# takeout
# lived
# from
# the
# family
# call
# how
# nights
# sleeping
# bike
# conjoined
# sleepovers
# a
# home
# how
# special
# swims
# bathtub
# special
# nights
# meals
# place
# brunch
# learning
# daytime
# to
# rides
# a
# girlfriend
# that
# a
# best
# movie
# above
# with
# mom
# cae
# dreaming
# drive
# fireplace
# dinner
# lessons
# pasta
# recipes
# bedrooms
# cooked
# nights
# piano
# bbq
# family
# hawk
# friends
# learning
# playing
# runs
# i
# learning
# piano

# %%
#experimenting with random shuffle
import random

mypoem = ['a', 'special', 'place', 'conjoined', 'childhood', 'bedrooms', 'bike', 'rides', 'family', 'dinner', 'family', 'movie', 'nights', 'sleepovers', 'sleepless', 'nights', 'dreaming', 'daytime', 'runs', 'swims', 'christmas', 'girlfriend', 'boyfriend', 'best', 'friends', 'pasta', 'nights', 'piano', 'playing', 'piano', 'lessons', 'brunch', 'baking', 'with', 'cae', 'learning', 'recipes', 'from', 'mom', 'learning', 'how', 'to', 'drive', 'learning', 'how', 'to', 'operate', 'a', 'bbq', 'fireplace', 'bathtub', 'sleeping', 'in', 'the', 'hawk', 'that', 'lived', 'above', 'us', 'takeout', 'home', 'cooked', 'meals', 'a', 'special', 'place', 'i', 'call', 'home']
random.shuffle(mypoem)

print(mypoem)
# Out:
# ['family', 'brunch', 'learning', 'lived', 'mom', 'recipes', 'rides', 'pasta', 'playing', 'the', 'learning', 'a', 'learning', 'drive', 'to', 'nights', 'above', 'piano', 'how', 'bbq', 'call', 'to', 'best', 'movie', 'daytime', 'operate', 'lessons', 'sleepless', 'nights', 'friends', 'boyfriend', 'home', 'bedrooms', 'with', 'runs', 'dreaming', 'dinner', 'a', 'meals', 'from', 'cae', 'that', 'a', 'takeout', 'home', 'conjoined', 'swims', 'in', 'sleeping', 'christmas', 'place', 'cooked', 'sleepovers', 'baking', 'bathtub', 'special', 'fireplace', 'i', 'place', 'girlfriend', 'nights', 'bike', 'us', 'hawk', 'childhood', 'special', 'piano', 'family', 'how']

# %%
for m in mypoem:
    print(m)
# Out:
# family
# brunch
# learning
# lived
# mom
# recipes
# rides
# pasta
# playing
# the
# learning
# a
# learning
# drive
# to
# nights
# above
# piano
# how
# bbq
# call
# to
# best
# movie
# daytime
# operate
# lessons
# sleepless
# nights
# friends
# boyfriend
# home
# bedrooms
# with
# runs
# dreaming
# dinner
# a
# meals
# from
# cae
# that
# a
# takeout
# home
# conjoined
# swims
# in
# sleeping
# christmas
# place
# cooked
# sleepovers
# baking
# bathtub
# special
# fireplace
# i
# place
# girlfriend
# nights
# bike
# us
# hawk
# childhood
# special
# piano
# family
# how

# %%
#experimenting with random shuffle
import random

mypoem = ['a', 'special', 'place', 'conjoined', 'childhood', 'bedrooms', 'bike', 'rides', 'family', 'dinner', 'family', 'movie', 'nights', 'sleepovers', 'sleepless', 'nights', 'dreaming', 'daytime', 'runs', 'swims', 'christmas', 'girlfriend', 'boyfriend', 'best', 'friends', 'pasta', 'nights', 'piano', 'playing', 'piano', 'lessons']
mypoem2 = ['brunch', 'baking', 'with', 'cae', 'learning', 'recipes', 'from', 'mom', 'learning', 'how', 'to', 'drive', 'learning', 'how', 'to', 'operate', 'a', 'bbq', 'fireplace', 'bathtub', 'sleeping', 'in', 'the', 'hawk', 'that', 'lived', 'above', 'us', 'takeout', 'home', 'cooked', 'meals', 'a', 'special', 'place', 'i', 'call', 'home']
random.shuffle(mypoem)
random.shuffle(mypoem2)

for x in mypoem:
  for y in mypoem2:
    print(x, y)
# Out:
# piano to
# piano call
# piano the
# piano home
# piano i
# piano home
# piano us
# piano cooked
# piano how
# piano baking
# piano operate
# piano above
# piano recipes
# piano bathtub
# piano to
# piano brunch
# piano meals
# piano in
# piano bbq
# piano a
# piano learning
# piano drive
# piano sleeping
# piano lived
# piano learning
# piano learning
# piano cae
# piano place
# piano fireplace
# piano special
# piano from
# piano that
# piano hawk
# piano a
# piano with
# piano takeout
# piano mom
# piano how
# lessons to
# lessons call
# lessons the
# lessons home
# lessons i
# lessons home
# lessons us
# lessons cooked
# lessons how
# lessons baking
# lessons operate
# lessons above
# lessons recipes
# lessons bathtub
# lessons to
# lessons brunch
# lessons meals
# lessons in
# lessons bbq
# lessons a
# lessons learning
# lessons drive
# lessons sleeping
# lessons lived
# lessons learning
# lessons learning
# lessons cae
# lessons place
# lessons fireplace
# lessons special
# ...

# %%
#POEM III Final

import random

mypoem = ['conjoined', 'childhood', 'bedrooms', 'bike', 'rides', 'family', 'dinner', 'family', 'movie', 'nights', 'sleepovers', 'sleepless', 'nights', 'dreaming', 'daytime', 'runs', 'swims', 'christmas', 'girlfriend', 'boyfriend', 'best', 'friends', 'pasta', 'nights', 'piano', 'playing', 'piano', 'lessons', 'brunch', 'baking', 'with', 'cae', 'learning', 'recipes', 'from', 'mom', 'learning', 'how', 'to', 'drive', 'learning', 'how', 'to', 'operate', 'a', 'bbq', 'fireplace', 'bathtub', 'sleeping', 'in', 'the', 'hawk', 'that', 'lived', 'above', 'us', 'takeout', 'home', 'cooked', 'meals',]
random.shuffle(mypoem)

print ('a special place')
print('\n')
for m in mypoem:
    print(m)
print('\n')
print ('a special place...i call home')
# Out:
# a special place
#
#
# recipes
# family
# baking
# to
# hawk
# the
# runs
# drive
# boyfriend
# bbq
# fireplace
# us
# girlfriend
# bike
# daytime
# dinner
# nights
# playing
# dreaming
# operate
# bathtub
# piano
# how
# sleeping
# that
# above
# from
# movie
# with
# friends
# sleepovers
# sleepless
# lessons
# cae
# nights
# best
# brunch
# piano
# nights
# learning
# swims
# pasta
# conjoined
# meals
# how
# family
# home
# a
# mom
# christmas
# rides
# learning
# takeout
# learning
# bedrooms
# lived
# to
# childhood
# cooked
# in
#
#
# a special place...i call home
